# %% [markdown]
# ### DOCUMENTACIÓN
#
# #### **1. TEMA, PROBLEMA Y SOLUCIÓN**
#
# **TEMA:** Este proyecto simula la gestión de una Tienda a partir de datos sintéticos.
#
# **PROBLEMA Y SOLUCIÓN:** El objetivo es determinar cuál es el medio de pago más utilizado por los clientes en la Tienda.
#
# #### **2. DATASET DE REFERENCIA: FUENTE, DEFINICIÓN, ESTRUCTURA, TIPOS Y ESCALA DE MEDICIÓN.**
#
# **Fuente:** Datos sintéticos educativos, generados por Guayerd e IBM.
#
# **Definición:** Base de datos que representa una Tienda, con catálogo de productos, registro de clientes y operaciones de venta.
#
# **Productos** (productos.csv) ~ 100 filas
# | Campo           | Tipo  | Escala    |
# | --------------- | ----- | --------- |
# | id_producto     | int   | Nominal   |
# | nombre_producto | str   | Nominal   |
# | categoria       | str   | Nominal   |
# | precio_unitario | int   | Razón     |
#
# **Clientes** (clientes.csv) ~ 100 filas
# | Campo           | Tipo  | Escala    |
# | --------------- | ----- | --------- |
# | id_cliente      | int   | Nominal   |
# | nombre_cliente  | str   | Nominal   |
# | ciudad          | str   | Nominal   |
# | fecha_alta      | date  | Intervalo |
#
# **Ventas** (ventas.csv) ~ 120 filas
# | Campo           | Tipo  | Escala    |
# | --------------- | ----- | --------- |
# | id_venta        | int   | Nominal   |
# | fecha           | dat   | Intervalo |
# | id_cliente      | int   | Nominal   |
# | nombre_cliente  | strin | Nominal   |
# | email           | str   | Nominal   |
# | medio_pago      | str   | Nominal   |
#
# **Detalle Ventas** (detalle_ventas.csv) ~ 300 filas
# | Campo           | Tipo  | Escala    |
# | --------------- | ----- | --------- |
# | id_venta        | int   | Nominal   |
# | id_producto     | int   | Nominal   |
# | nombre_producto | str   | Nominal   |
# | cantidad        | int   | Razón     |
# | precio_unitario | str   | Razón     |
# | importe         | int   | Razón     |
#
# #### **3. PASOS, PSEUDOCÓDIGO Y DIAGRAMA DEL PROGRAMA (SPRINT1)**
#
# Generamos un menú para que el usuario pueda seleccionar una opción determinada según la información que desee obtener.
#
# ##### **3.1 Pasos**
#
# 1) Mostrar un menú numérico con las opciones disponibles.
# 2) Imprimir un texto en pantalla asociado a la opción escogida por el usuario.
# 3) Mantener acceso al menú hasta escoger la opción "Salir".
# 4) Devolver al usuario un mensaje de "Opción no válida. Intenta de nuevo." en caso de insertar un valor numérico distinto a los que están disponibles en el menú.
#
# ##### **3.2 Pseudocódigo**

# %%
INICIO
    Mientras True:
        Mostrar opciones:
            1. Tema, problema y solución
            2. Dataset de referencia
            3. Pasos, pseudocódigo y diagrama
            4. Sugerencias y mejoras con Copilot
            5. Salir
        Leer opción
        Si opción == 5:
            Romper bucle
        Sino si opción >= 1 y opción <= 4:
            Imprimir texto asociado
        Sino:
            Imprimir 'Opción inválida'
FIN
# Out:
#   Cell In[1], line 2
#     Mientras True mostrar opciones:
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# ##### **3.3 Diagrama de flujo: archivo "Diagrama_Flujo.png" en la carpeta del proyecto**
#
# #### **4. SUGERENCIAS Y MEJORAS APLICADAS CON COPILOT**
#
# - Se creó un menú con 5 opciones que imprime texto asociado a la opción elegida.
# - Se optimizó el pseudocódigo para que, en caso de ingresar un valor numérico distinto a los del menú, imprima "Opción inválida".
